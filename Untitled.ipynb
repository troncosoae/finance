# %%
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime

# %%
start_time = '2021-01-01'
end_time = '2022-01-01'
# end_time = datetime.today().strftime('%Y-%m-%d')

apple_stock = web.DataReader(name='aapl', data_source='yahoo', start=start_time, end=end_time)
apple_stock
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-01-04  133.610001  126.760002  133.520004  129.410004  143301900.0
# 2021-01-05  131.740005  128.429993  128.889999  131.009995   97664900.0
# 2021-01-06  131.050003  126.379997  127.720001  126.599998  155088000.0
# 2021-01-07  131.630005  127.860001  128.360001  130.919998  109578200.0
# 2021-01-08  132.630005  130.229996  132.429993  132.050003  105158200.0
# ...                ...         ...         ...         ...          ...
# 2021-12-27  180.419998  177.070007  177.089996  180.330002   74919600.0
# 2021-12-28  181.330002  178.529999  180.160004  179.289993   79144300.0
# 2021-12-29  180.630005  178.139999  179.330002  179.380005   62348900.0
# 2021-12-30  180.570007  178.089996  179.470001  178.199997   59773000.0
# 2021-12-31  179.229996  177.259995  178.089996  177.570007   64062300.0
#
#              Adj Close
# Date
# 2021-01-04  128.264969
# 2021-01-05  129.850845
# ...

# %%
type(apple_stock)
# Out:
# pandas.core.frame.DataFrame

# %%
sp500 = web.DataReader(name='ivv', data_source='yahoo', start=start_time, end=end_time)
sp500
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2021-01-04  376.820007  366.160004  376.690002  370.220001  7103700.0
# 2021-01-05  373.829987  369.440002  369.440002  372.670013  4310500.0
# 2021-01-06  378.369995  370.459991  371.019989  374.920013  4343100.0
# 2021-01-07  381.260010  377.279999  377.470001  380.470001  6051700.0
# 2021-01-08  382.859985  378.489990  382.010010  382.640015  3400200.0
# ...                ...         ...         ...         ...        ...
# 2021-12-27  479.399994  474.079987  474.079987  479.399994  4128500.0
# 2021-12-28  480.899994  478.119995  479.839996  479.029999  4262300.0
# 2021-12-29  480.640015  478.000000  479.079987  479.529999  3312100.0
# 2021-12-30  481.089996  477.760010  480.040009  478.179993  4030600.0
# 2021-12-31  478.929993  476.750000  477.660004  476.989990  3980100.0
#
#              Adj Close
# Date
# 2021-01-04  363.011169
# 2021-01-05  365.413513
# 2021-01-06  367.619720
# ...

# %%
sp500.mean()
# Out:
# High         4.298083e+02
# Low          4.258111e+02
# Open         4.278833e+02
# Close        4.280344e+02
# Volume       4.485096e+06
# Adj Close    4.221133e+02
# dtype: float64

# %%
sp500['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sp500.diff()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 2021-01-04       NaN       NaN       NaN       NaN        NaN        NaN
# 2021-01-05 -2.990021  3.279999 -7.250000  2.450012 -2793200.0   2.402344
# 2021-01-06  4.540009  1.019989  1.579987  2.250000    32600.0   2.206207
# 2021-01-07  2.890015  6.820007  6.450012  5.549988  1708600.0   5.441864
# 2021-01-08  1.599976  1.209991  4.540009  2.170013 -2651500.0   2.127808
# ...              ...       ...       ...       ...        ...        ...
# 2021-12-27  5.169983  3.369995  3.259979  6.769989  -240300.0   6.726624
# 2021-12-28  1.500000  4.040009  5.760010 -0.369995   133800.0  -0.367615
# 2021-12-29 -0.259979 -0.119995 -0.760010  0.500000  -950200.0   0.496796
# 2021-12-30  0.449982 -0.239990  0.960022 -1.350006   718500.0  -1.341370
# 2021-12-31 -2.160004 -1.010010 -2.380005 -1.190002   -50500.0  -1.182404
#
# [252 rows x 6 columns]

# %%
sp500.diff()['Close'].mean()
# Out:
# 0.42537844228554533

# %%
sp500.diff()['Close'].corr(apple_stock.diff()['Close'])
# Out:
# 0.6790780090226577

# %%
sp500.diff()['Close'].corr(sp500.diff()['Close'])
# Out:
# 1.0

# %%
ezu = web.DataReader(name='ezu', data_source='yahoo', start=start_time, end=end_time)
ezu
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2021-01-04  45.320000  44.330002  45.279999  44.599998   4195600.0  42.553040
# 2021-01-05  44.959999  44.480000  44.529999  44.860001   2190600.0  42.801109
# 2021-01-06  45.599998  45.029999  45.090000  45.380001   4334200.0  43.297237
# 2021-01-07  45.619999  45.360001  45.419998  45.570000  10396000.0  43.478516
# 2021-01-08  45.840000  45.369999  45.740002  45.799999   3799300.0  43.697964
# ...               ...        ...        ...        ...         ...        ...
# 2021-12-27  49.220001  48.849998  48.849998  49.220001   1772500.0  47.999344
# 2021-12-28  49.330002  49.139999  49.230000  49.230000   2961400.0  48.009094
# 2021-12-29  49.320000  49.080002  49.139999  49.270000   3676400.0  48.048100
# 2021-12-30  49.209999  48.950001  49.160000  49.000000   2972600.0  47.902435
# 2021-12-31  49.299999  48.959999  49.110001  49.009998   3993500.0  47.912212
#
# [252 rows x 6 columns]

# %%
sp500.diff()['Close'].corr(ezu.diff()['Close'])
# Out:
# 0.7868104627205457
